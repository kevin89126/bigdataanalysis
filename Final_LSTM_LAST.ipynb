# %% [markdown]
# ## Import CSV

# %%
import pandas
def read_csv(filename,folder):
    folder=folder+"/"+filename+".csv"
    return pandas.read_csv(folder,encoding='ISO-8859-1')

# %%
folder="/nfs/Workspace/"
data=read_csv(filename="FINAL_TRAIN",folder=folder)
data.columns = ( 'DATE','vfx' ,'vbx', 'vmt','rwm','dog','psh','spx')
data = data.fillna(method='ffill')
data.head()
# Out:
#         DATE         vfx       vbx        vmt        rwm        dog  \
# 0   2017/5/5  208.064148  9.794650  24.294504  45.874645  69.404022
# 1  2017/5/12  207.510513  9.812943  24.159153  46.313114  69.716293
# 2  2017/5/19  206.844238  9.858670  24.178493  46.839294  69.950508
# 3  2017/5/26  209.875275  9.849524  24.255835  46.303379  69.052704
# 4   2017/6/2  211.977325  9.915467  24.719877  45.494625  68.545250
#
#          psh          spx
# 0  32.990784  4615.089844
# 1  33.087994  4602.959961
# 2  33.185196  4588.350098
# 3  32.718620  4655.649902
# 4  32.388126  4702.560059

# %%
from matplotlib import pyplot
def plot_data(dataset,groups):
    i = 1
    pyplot.figure()
    values = dataset.values
    for group in groups:
    	pyplot.subplot(len(groups), 1, i)
    	pyplot.plot(values[:, group])
    	pyplot.title(dataset.columns[group], y=0.5, loc='right')
    	i += 1
    pyplot.show()

# %%
plot_data(data,groups=list(range(1,8)))

# %% [markdown]
# ## Data Summary

# %%
data.describe()
# Out:
#               vfx         vbx         vmt         rwm         dog         psh  \
# count  174.000000  174.000000  174.000000  174.000000  174.000000  174.000000
# mean   252.023549   10.351102   25.249413   40.581595   56.158490   27.554384
# std     26.528003    0.605221    2.388251    3.513995    5.956887    3.019515
# min    206.844238    9.711603   20.059999   32.709999   42.669998   19.610001
# 25%    233.126881    9.858670   23.598254   38.131068   52.490212   25.895415
# 50%    248.611587    9.997527   24.723773   40.383860   55.455484   27.737020
# 75%    268.835609   10.844124   27.637063   42.220478   58.673307   29.445991
# max    323.280121   11.721215   30.474449   55.535786   69.950508   33.185196
#
#                spx
# count   174.000000
# mean   5604.535628
# std     596.803618
# min    4588.350098
# 25%    5186.832398
# 50%    5528.060059
# 75%    5984.462403
# max    7207.100098

# %% [markdown]
# ## Independent and identically distributed (I.I.D.) Testing

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
sm.graphics.tsa.plot_acf(data['vfx'].values, lags=40)
plt.show()

# %% [markdown]
# ## *** LSTM ***

# %%
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
def Standard_MinMax(data):
    sc = MinMaxScaler(feature_range = (0, 1))
    
    return sc.fit_transform(data.reshape(-1,1))

# %%
#folder="/Users/wenyongjing/Downloads/第二章"
#data=read_csv(filename="WEN",folder=folder)
#data.columns = ( 'DATE','vfx','vix' ,'vbx', 'vmt','rwm','dog','psh', 'spx')
del data['DATE']
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(data)
data.head()
# Out:
#           vfx       vbx        vmt        rwm        dog        psh  \
# 0  208.064148  9.794650  24.294504  45.874645  69.404022  32.990784
# 1  207.510513  9.812943  24.159153  46.313114  69.716293  33.087994
# 2  206.844238  9.858670  24.178493  46.839294  69.950508  33.185196
# 3  209.875275  9.849524  24.255835  46.303379  69.052704  32.718620
# 4  211.977325  9.915467  24.719877  45.494625  68.545250  32.388126
#
#            spx
# 0  4615.089844
# 1  4602.959961
# 2  4588.350098
# 3  4655.649902
# 4  4702.560059

# %% [markdown]
# ## Series to Supervised

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pandas.DataFrame(data)
	cols, names = list(), list()
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pandas.concat(cols, axis=1)
	agg.columns = names
    
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
reframed = series_to_supervised(scaled, 1, 1)
reframed.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.010477   0.041325   0.406599   0.576744   0.979968   0.985679
# 2   0.005722   0.050428   0.393603   0.595954   0.991415   0.992840
# 3   0.000000   0.073182   0.395460   0.619006   1.000000   1.000000
# 4   0.026032   0.068631   0.402886   0.595527   0.967090   0.965630
# 5   0.044085   0.101445   0.447443   0.560096   0.948489   0.941285
#
#    var7(t-1)   var1(t)   var2(t)   var3(t)   var4(t)   var5(t)   var6(t)  \
# 1   0.010211  0.005722  0.050428  0.393603  0.595954  0.991415  0.992840
# 2   0.005579  0.000000  0.073182  0.395460  0.619006  1.000000  1.000000
# 3   0.000000  0.026032  0.068631  0.402886  0.595527  0.967090  0.965630
# 4   0.025699  0.044085  0.101445  0.447443  0.560096  0.948489  0.941285
# 5   0.043612  0.039088  0.087766  0.431662  0.536617  0.939903  0.948446
#
#     var7(t)
# 1  0.005579
# 2  0.000000
# 3  0.025699
# 4  0.043612
# 5  0.038736

# %%
pred = {'vfx': 7}
reframed = pandas.concat([reframed.iloc[:,0:7],reframed.iloc[:,pred['vfx']]],axis=1)
reframed.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.010477   0.041325   0.406599   0.576744   0.979968   0.985679
# 2   0.005722   0.050428   0.393603   0.595954   0.991415   0.992840
# 3   0.000000   0.073182   0.395460   0.619006   1.000000   1.000000
# 4   0.026032   0.068631   0.402886   0.595527   0.967090   0.965630
# 5   0.044085   0.101445   0.447443   0.560096   0.948489   0.941285
#
#    var7(t-1)   var1(t)
# 1   0.010211  0.005722
# 2   0.005579  0.000000
# 3   0.000000  0.026032
# 4   0.025699  0.044085
# 5   0.043612  0.039088

# %%
reframed.shape
# Out:
# (173, 8)

# %% [markdown]
# ## Data Split

# %%
train = reframed.values[:100,:]
test = reframed.values[100:174,:]
train_X, train_y = train[:, :-1], train[:, -1]
test_X , test_y  = test[:, :-1], test[:, -1]
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((100, 7), (100,), (73, 7), (73,))

# %% [markdown]
# ## LSTM

# %%
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X  = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
train_X.shape, train_y.shape, test_X.shape, test_y.shape

import keras
from keras import layers
from keras.layers import Dropout

model = keras.models.Sequential()
model.add(layers.LSTM(8, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(layers.Dense(1))
#model.add(Dropout(0.5))
model.compile(loss='mse', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_10 (LSTM)               (None, 8)                 512
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 521
# Trainable params: 521
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
history = model.fit(train_X, train_y, epochs=80, 
                    batch_size=9, validation_data=(test_X, test_y), 
                    verbose=1, shuffle=False)
# Out:
# Epoch 1/80
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0814 - val_loss: 0.2547
# Epoch 2/80
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0516 - val_loss: 0.1986
# Epoch 3/80
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0302 - val_loss: 0.1525
# Epoch 4/80
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0169 - val_loss: 0.1171
# Epoch 5/80
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0104 - val_loss: 0.0925
# Epoch 6/80
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0083 - val_loss: 0.0768
# Epoch 7/80
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0080 - val_loss: 0.0677
# Epoch 8/80
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0081 - val_loss: 0.0624
# Epoch 9/80
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0079 - val_loss: 0.0591
# Epoch 10/80
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0076 - val_loss: 0.0565
# Epoch 11/80
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0540
# Epoch 12/80
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0514
# Epoch 13/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0487
# Epoch 14/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0460
# Epoch 15/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0433
# Epoch 16/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0408
# Epoch 17/80
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0383
# Epoch 18/80
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 0.0359
# Epoch 19/80
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0336
# Epoch 20/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0314
# Epoch 21/80
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0294
# Epoch 22/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0274
# Epoch 23/80
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0255
# Epoch 24/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0237
# Epoch 25/80
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0220
# Epoch 26/80
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 0.0204
# Epoch 27/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0190
# Epoch 28/80
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0176
# Epoch 29/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0163
# Epoch 30/80
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0151
# Epoch 31/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0140
# Epoch 32/80
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0130
# Epoch 33/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0121
# Epoch 34/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0113
# Epoch 35/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0106
# Epoch 36/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0099
# Epoch 37/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0093
# Epoch 38/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0088
# Epoch 39/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0083
# Epoch 40/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0079
# Epoch 41/80
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0075
# Epoch 42/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0072
# Epoch 43/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0069
# Epoch 44/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 45/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0065
# Epoch 46/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0064
# Epoch 47/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0063
# Epoch 48/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0062
# Epoch 49/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0062
# Epoch 50/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0062
# Epoch 51/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0062
# Epoch 52/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0062
# Epoch 53/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0063
# Epoch 54/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0064
# Epoch 55/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0065
# Epoch 56/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0066
# Epoch 57/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0067
# Epoch 58/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0069
# Epoch 59/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0070
# Epoch 60/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0072
# Epoch 61/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0074
# Epoch 62/80
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0075
# Epoch 63/80
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0077
# Epoch 64/80
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0079
# Epoch 65/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0081
# Epoch 66/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0083
# Epoch 67/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0085
# Epoch 68/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0088
# Epoch 69/80
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0090
# Epoch 70/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0092
# Epoch 71/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0094
# Epoch 72/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0096
# Epoch 73/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0098
# Epoch 74/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0101
# Epoch 75/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0103
# Epoch 76/80
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0105
# Epoch 77/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0107
# Epoch 78/80
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0109
# Epoch 79/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0111
# Epoch 80/80
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0113

# %% [markdown]
# ## Plot Loss Curve

# %%
# %pylab inline
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/conda/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['test', 'real']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ## Model Predict

# %%
import datetime
folder="/nfs/Workspace/"
pred_data=read_csv(filename="FINAL_PRED",folder=folder)
pred_data.columns = ( 'Date','vfx','vbx', 'vmt','rwm','dog','psh', 'spx')
#pred_data.isnull().sum()
pred_data = pred_data.fillna(method='ffill')
pred_data_bkp = np.array(pred_data['vfx']);
# Copy Last date to tomorrow
tmp = pred_data[-1:].values.tolist()
tomorrow = datetime.date.today() + datetime.timedelta(days=1)
tomorrow = tomorrow.strftime("%y%y/%m/%d")
tmp[0][0] = tomorrow
pred_data.loc[len(pred_data)] = tmp[0]
print(pred_data)
print(pred_data_bkp)
# Out:
#           Date         vfx        vbx        vmt        rwm        dog  \
# 0    2020/5/15  262.640198  11.370819  21.541000  42.529999  52.959999
# 1    2020/5/22  271.224365  11.410404  22.011000  39.230000  51.099998
# 2    2020/5/29  279.471558  11.452066  22.191000  38.020000  49.169998
# 3     2020/6/5  293.309326  11.392575  22.420000  35.040001  45.970001
# 4    2020/6/12  279.431885  11.471897  21.871000  37.779999  48.330002
# 5    2020/6/19  284.685486  11.501643  22.117001  36.869999  47.799999
# 6    2020/6/26  276.529541  11.521473  21.972000  37.919998  49.299999
# 7     2020/7/6  292.335510  11.542351  22.490000  36.099998  46.860001
# 8    2020/7/10  292.903198  11.582084  22.513000  36.590000  47.230000
# 9    2020/7/17  296.618164  11.611882  22.853001  35.209999  46.110001
# 10   2020/7/24  295.811432  11.661548  22.733000  35.320000  46.430000
# 11   2020/7/31  301.000397  11.711266  23.090000  34.980000  46.470001
# 12    2020/8/7  308.480102  11.721215  23.469000  32.950001  44.740002
# 13   2020/8/14  310.601471  11.601814  23.580000  32.750000  43.869999
# 14   2020/8/21  312.971893  11.631664  23.660000  33.270000  43.820000
# 15   2020/8/28  323.280121  11.552064  23.839001  32.709999  42.669998
# 16    2020/9/4  315.939880  11.611867  23.386999  33.590000  43.400002
# 17   2020/9/11  308.061798  11.621835  23.320000  34.380001  44.049999
# 18   2020/9/18  306.189362  11.611867  23.801001  33.430000  44.049999
# 19   2020/9/25  304.307007  11.601900  23.437000  34.750000  44.759998
# 20   2020/10/2  309.019989  11.600902  24.082001  33.259998  43.910000
# 21   2020/10/9  321.040008  11.560967  24.799000  31.180000  42.480000
# 22  2020/10/16  321.690002  11.590918  24.627001  31.240000  42.439999
# 23  2020/10/23  320.029999  11.531016  24.289000  31.059999  42.790001
# 24  2020/10/30  302.040008  11.530000  23.377001  33.040001  45.680000
# 25   2020/11/6  324.190002  11.600000  24.267000  30.840000  42.680000
# 26  2020/11/13  331.429993  11.580000  23.688000  28.990000  40.880001
# 27  2020/11/20  329.010010  11.640000  23.980000  28.320000  41.130001
# 28  2020/11/27  336.559998  11.640000  24.520000  27.219999  40.209999
# 29   2020/12/4  342.359985  11.580000  24.618000  26.650000  39.740002
# 30  2020/12/09  342.359985  11.580000  24.618000  26.650000  39.740002
#
#           psh          spx
# 0   24.480000  5852.839844
# 1   23.670000  6044.160156
# 2   22.980000  6227.810059
# 3   21.870001  6536.580078
# 4   22.850000  6227.419922
# 5   22.420000  6344.700195
# 6   23.020000  6163.500000
# 7   21.770000  6516.049805
# 8   21.709999  6528.959961
# 9   21.420000  6611.859863
# 10  21.480000  6594.100098
# 11  21.110001  6709.810059
# 12  20.580000  6876.649902
# 13  20.420000  6924.279785
# 14  20.260000  6977.270020
# 15  19.610001  7207.100098
# 16  20.030001  7043.620117
# 17  20.510000  6868.220215
# 18  20.620001  6826.720215
# 19  20.730000  6784.950195
# 20  20.379999  6889.600098
# 21  19.590000  7157.939941
# 22  19.580000  7172.700195
# 23  19.650000  7135.810059
# 24  20.750000  6734.839844
# 25  19.330000  7230.509766
# 26  18.900000  7390.609863
# 27  19.030001  7336.759766
# 28  18.590000  7505.379883
# 29  18.260000  7634.770020
# 30  18.260000  7634.770020
# [262.6401978 271.2243652 279.4715576 293.3093262 279.4318848 284.6854858
#  276.529541  292.3355103 292.9031982 296.6181641 295.8114319 301.0003967
#  308.4801025 310.6014709 312.9718933 323.2801208 315.9398804 308.0617981
#  306.1893616 304.3070068 309.019989  321.0400085 321.6900024 320.0299988
#  302.0400085 324.1900024 331.4299927 329.0100098 336.5599976 342.3599854]

# %%
del pred_data['Date']
scaler = MinMaxScaler(feature_range=(0, 1))
pred_scaled = scaler.fit_transform(pred_data)
pred_data.head()
# Out:
#           vfx        vbx     vmt        rwm        dog        psh          spx
# 0  262.640198  11.370819  21.541  42.529999  52.959999  24.480000  5852.839844
# 1  271.224365  11.410404  22.011  39.230000  51.099998  23.670000  6044.160156
# 2  279.471558  11.452066  22.191  38.020000  49.169998  22.980000  6227.810059
# 3  293.309326  11.392575  22.420  35.040001  45.970001  21.870001  6536.580078
# 4  279.431885  11.471897  21.871  37.779999  48.330002  22.850000  6227.419922

# %%
pred_reframed = series_to_supervised(pred_scaled, 1, 1)
pred_reframed.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.000000   0.000000   0.000000   1.000000   1.000000   1.000000
# 2   0.107679   0.112972   0.144260   0.792191   0.859304   0.869775
# 3   0.211132   0.231873   0.199509   0.715995   0.713313   0.758842
# 4   0.384712   0.062090   0.269797   0.528338   0.471256   0.580386
# 5   0.210634   0.288468   0.101289   0.700882   0.649773   0.737942
#
#    var7(t-1)   var1(t)   var2(t)   var3(t)   var4(t)   var5(t)   var6(t)  \
# 1   0.000000  0.107679  0.112972  0.144260  0.792191  0.859304  0.869775
# 2   0.107367  0.211132  0.231873  0.199509  0.715995  0.713313  0.758842
# 3   0.210429  0.384712  0.062090  0.269797  0.528338  0.471256  0.580386
# 4   0.383708  0.210634  0.288468  0.101289  0.700882  0.649773  0.737942
# 5   0.210210  0.276535  0.373361  0.176796  0.643577  0.609682  0.668810
#
#     var7(t)
# 1  0.107367
# 2  0.210429
# 3  0.383708
# 4  0.210210
# 5  0.276027

# %%
pred = {'vfx': 7}
pred_reframed = pandas.concat([pred_reframed.iloc[:,0:7],pred_reframed.iloc[:,pred['vfx']]],axis=1)
pred_reframed.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.000000   0.000000   0.000000   1.000000   1.000000   1.000000
# 2   0.107679   0.112972   0.144260   0.792191   0.859304   0.869775
# 3   0.211132   0.231873   0.199509   0.715995   0.713313   0.758842
# 4   0.384712   0.062090   0.269797   0.528338   0.471256   0.580386
# 5   0.210634   0.288468   0.101289   0.700882   0.649773   0.737942
#
#    var7(t-1)   var1(t)
# 1   0.000000  0.107679
# 2   0.107367  0.211132
# 3   0.210429  0.384712
# 4   0.383708  0.210634
# 5   0.210210  0.276535

# %%
pred_test = pred_reframed.values[:,:]
pred_test_X , pred_test_y  = pred_test[:, :-1], pred_test[:, -1]
pred_test_X.shape, pred_test_y.shape
# Out:
# ((30, 7), (30,))

# %%
pred_test_X  = pred_test_X.reshape((pred_test_X.shape[0], 1, pred_test_X.shape[1]))
pred_test_X.shape, pred_test_y.shape

pred_yhat = model.predict(pred_test_X)

pred_test_X = pred_test_X.reshape((pred_test_X.shape[0], pred_test_X.shape[2]))
pred_yhat.shape, pred_test_X.shape
# Out:
# ((30, 1), (30, 7))

# %% [markdown]
# ## Invert scaling for forecast

# %%
pred = {'VFINX': 0}
pred_inv_yhat = concatenate((pred_yhat, numpy.delete(pred_test_X, pred['VFINX'], axis=1)), axis=1)
pred_inv_yhat = scaler.inverse_transform(pred_inv_yhat)
pred_inv_yhat = pred_inv_yhat[:,0]
pred_inv_yhat.shape,pred_inv_yhat
# Out:
# ((30,),
#  array([255.12493574, 266.0626612 , 276.15490129, 287.22326232,
#         277.83640907, 284.45778347, 277.68657823, 293.96387393,
#         295.81975492, 302.91036026, 304.51635332, 311.58600142,
#         321.55724707, 317.15238281, 320.30541021, 323.52760766,
#         320.96990745, 314.71509941, 313.99056482, 309.94397645,
#         315.66574694, 324.04074521, 326.56294095, 321.05279082,
#         304.4575324 , 328.80386636, 333.75657437, 336.8806736 ,
#         342.73597551, 342.19950251]))

# %% [markdown]
# ## Invert scaling for actual

# %%
real = pred_test_y.reshape((len(pred_test_y), 1))
inv_y = concatenate((real, numpy.delete(pred_test_X, pred['VFINX'], axis=1)), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
inv_y
# Out:
# array([271.2243652, 279.4715576, 293.3093262, 279.4318848, 284.6854858,
#        276.529541 , 292.3355103, 292.9031982, 296.6181641, 295.8114319,
#        301.0003967, 308.4801025, 310.6014709, 312.9718933, 323.2801208,
#        315.9398804, 308.0617981, 306.1893616, 304.3070068, 309.019989 ,
#        321.0400085, 321.6900024, 320.0299988, 302.0400085, 324.1900024,
#        331.4299927, 329.0100098, 336.5599976, 342.3599854, 342.3599854])

# %% [markdown]
# ## RMSE

# %%
from sklearn.metrics import mean_squared_error
rmse = sqrt(mean_squared_error(inv_y, pred_inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 9.288

# %%
from RegscorePy import *
aic.aic(inv_y, pred_inv_yhat, 367)
# Out:
# 867.7232418122722

# %%
#inv_y = np.cumprod(inv_y+1)
#inv_yhat = np.cumprod(inv_yhat+1)
len(inv_y),len(pred_inv_yhat)
# Out:
# (30, 30)

# %% [markdown]
# ## Predict vs Real

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.plot(inv_y, color = 'red', label = 'Real')
plt.plot(pred_inv_yhat, color = 'blue', label = 'Predict')
plt.title('Real vs Predict')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## 將樣本數轉成報酬率

# %%
import array
print(pred_data_bkp)
samples = np.array(pred_data_bkp)
arr1 = []
for i in range(len(samples)-1):
  arr1.append((samples[i]+samples[i+1])/samples[i])

#轉換成報酬率
arr2 = np.array(arr1)
#標準差
std = np.std(arr2, ddof=1)

print(std)
# Out:
# [262.6401978 271.2243652 279.4715576 293.3093262 279.4318848 284.6854858
#  276.529541  292.3355103 292.9031982 296.6181641 295.8114319 301.0003967
#  308.4801025 310.6014709 312.9718933 323.2801208 315.9398804 308.0617981
#  306.1893616 304.3070068 309.019989  321.0400085 321.6900024 320.0299988
#  302.0400085 324.1900024 331.4299927 329.0100098 336.5599976 342.3599854]
# 0.029065834017770947

# %% [markdown]
# ## 算出最後一筆報酬率與標準差比較

# %%
pred_last1 = pred_data_bkp[len(pred_data_bkp)-1]
pred_last2 = pred_inv_yhat[len(pred_inv_yhat)-1]
newReturn = (pred_last1/pred_last2)/pred_last1

print(pred_last1),print(pred_last2)
print(newReturn)
# Out:
# 342.35998539999997
# 342.1995025102045
# 0.0029222719281135705

# %%
result_pred = pandas.DataFrame(pred_inv_yhat,columns =['Pred_VFNIX'])
temp =read_csv(filename="PRED_NEW",folder=folder)
temp.columns = ( 'Date','vfx','vix' ,'vbx', 'vmt','rwm','dog','psh', 'spx')                                                    
temp = temp[['Date','vfx']]
result = pandas.concat([temp,result_pred], axis = 1)
#result.to_csv('final_new.csv')
